-- %%
DECLARE OR REPLACE VAR catalog_use STRING DEFAULT current_catalog();
DECLARE OR REPLACE VAR schema_use STRING DEFAULT current_schema();

SET VAR catalog_use = :catalog_use;
SET VAR schema_use = :schema_use;

USE IDENTIFIER(catalog_use || '.' || schema_use);

-- DROP TABLE IF EXISTS adt_hl7_messages;
